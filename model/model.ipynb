# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, root_mean_squared_error, r2_score, f1_score, accuracy_score, confusion_matrix, roc_auc_score, roc_curve

# %%
df = pd.read_csv('cleaned_data.csv')
df.sample(10)
# Out:
#       user_id  subscription_type  number_of_playlists  skips_per_day  \
# 628  user_634                  1                    4              5
# 878  user_886                  0                    0              3
# 315  user_318                  1                    4              6
# 311  user_314                  0                    0              6
# 18    user_19                  1                    7              4
# 33    user_34                  1                    3              9
# 74    user_76                  0                    3              5
# 364  user_368                  1                    6              8
# 95    user_97                  1                    5              5
# 907  user_915                  1                    3              9
#
#      support_tickets  days_since_last_login  churned  country_AU  country_BR  \
# 628                0              -0.156115        0         0.0         0.0
# 878                1              -0.566227        0         0.0         0.0
# 315                1              -0.771282        1         0.0         0.0
# 311                0              -0.258643        1         0.0         0.0
# 18                 0              -0.873810        0         0.0         0.0
# 33                 0               0.048941        0         0.0         0.0
# 74                 0              -0.566227        0         0.0         1.0
# 364                1              -0.771282        1         0.0         0.0
# 95                 0               2.509610        1         0.0         0.0
# 907                0              -0.668754        0         0.0         0.0
#
#      country_CA  ...  country_UK  country_US  top_genre_Classical  \
# 628         0.0  ...         0.0         0.0                  0.0
# 878         0.0  ...         0.0         0.0                  1.0
# 315         0.0  ...         0.0         0.0                  0.0
# 311         0.0  ...         0.0         1.0                  0.0
# 18          0.0  ...         0.0         0.0                  0.0
# 33          0.0  ...         0.0         0.0                  0.0
# 74          0.0  ...         0.0         0.0                  0.0
# 364         1.0  ...         0.0         0.0                  0.0
# 95          0.0  ...         1.0         0.0                  0.0
# 907         0.0  ...         0.0         0.0                  1.0
#
#      top_genre_Country  top_genre_Electronic  top_genre_Hip-Hop  \
# 628                0.0                   0.0                0.0
# 878                0.0                   0.0                0.0
# 315                0.0                   0.0                0.0
# 311                0.0                   0.0                0.0
# 18                 0.0                   1.0                0.0
# 33                 0.0                   1.0                0.0
# 74                 0.0                   0.0                0.0
# 364                1.0                   0.0                0.0
# 95                 1.0                   0.0                0.0
# 907                0.0                   0.0                0.0
#
#      top_genre_Jazz  top_genre_Pop  top_genre_Rock  avg_daily_minutes
# 628             1.0            0.0             0.0           0.711913
# 878             0.0            0.0             0.0           0.380311
# 315             0.0            1.0             0.0           0.907535
# 311             1.0            0.0             0.0          -1.072534
# 18              0.0            0.0             0.0           1.100770
# 33              0.0            0.0             0.0           1.057829
# 74              0.0            0.0             1.0          -1.797764
# 364             0.0            0.0             0.0          -0.175539
# 95              0.0            0.0             0.0           0.678515
# 907             0.0            0.0             0.0          -0.204167
#
# [10 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['user_id', 'subscription_type', 'number_of_playlists', 'skips_per_day',
#        'support_tickets', 'days_since_last_login', 'churned', 'country_AU',
#        'country_BR', 'country_CA', 'country_DE', 'country_FR', 'country_IN',
#        'country_PK', 'country_RU', 'country_UK', 'country_US',
#        'top_genre_Classical', 'top_genre_Country', 'top_genre_Electronic',
#        'top_genre_Hip-Hop', 'top_genre_Jazz', 'top_genre_Pop',
#        'top_genre_Rock', 'avg_daily_minutes'],
#       dtype='object')

# %%
x = df.drop(['user_id', 'churned'], axis=1)
y = df['churned']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LogisticRegression(class_weight='balanced')
model.fit(x_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = model.predict(x_test)
print("Accuracy score", accuracy_score(y_test, y_pred))
# Out:
# Accuracy score 0.7236180904522613

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.72      0.81       158
#            1       0.41      0.73      0.52        41
#
#     accuracy                           0.72       199
#    macro avg       0.66      0.73      0.66       199
# weighted avg       0.81      0.72      0.75       199

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    class_weight='balanced',
    n_estimators=300,
    random_state=42,
)

rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88       158
#            1       0.50      0.10      0.16        41
#
#     accuracy                           0.79       199
#    macro avg       0.65      0.54      0.52       199
# weighted avg       0.74      0.79      0.73       199

# %%
print(f"f1 score: {f1_score(y_test, y_pred)}")
print(f"RMSE: {root_mean_squared_error(y_test, y_pred)}")
print(f"R2 score: {r2_score(y_test, y_pred)}")
# Out:
# f1 score: 0.5217391304347826
# RMSE: 0.5257203720113371
# R2 score: -0.6895646804569309

# %%
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# AUC score
auc_score = roc_auc_score(y_test, y_pred)

# plot
plt.plot(fpr, tpr, label=f"AUC = {auc_score:.2f}")
plt.plot([0, 1], [0, 1], linestyle="--")

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Logistic Regression")
plt.legend()
plt.show()
